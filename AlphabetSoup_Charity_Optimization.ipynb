# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
apptype_counts = application_df['APPLICATION_TYPE'].value_counts()
apptype_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(apptype_counts[apptype_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = application_df['CLASSIFICATION'].value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts_1 = class_counts.loc[class_counts > 1]
class_counts_1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_counts[class_counts < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_converted = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = application_converted.drop(['IS_SUCCESSFUL'], axis=1)
y = application_converted['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# Compile, Train, and Evaluate the Model

# %%
#Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
hidden_node1 = 80
hidden_node2 = 40
hidden_node3= 10

nn = tf.keras.models.Sequential()

# %%
# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_node1,
             input_dim=input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(
    units=hidden_node2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(
    units=hidden_node3, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 40)                3240
#
#  dense_2 (Dense)             (None, 10)                410
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 7181 (28.05 KB)
# Trainable params: 7181 (28.05 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 804/804 [==============================] - 4s 2ms/step - loss: 0.5767 - accuracy: 0.7181
# Epoch 2/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5565 - accuracy: 0.7307
# Epoch 3/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5527 - accuracy: 0.7310
# Epoch 4/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7322
# Epoch 5/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7330
# Epoch 6/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7338
# Epoch 7/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7336
# Epoch 8/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5474 - accuracy: 0.7357
# Epoch 9/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7339
# Epoch 10/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5459 - accuracy: 0.7342
# Epoch 11/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5454 - accuracy: 0.7360
# Epoch 12/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7359
# Epoch 13/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7359
# Epoch 14/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7349
# Epoch 15/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7371
# Epoch 16/30
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5434 - accuracy: 0.7369
# Epoch 17/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7371
# Epoch 18/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5429 - accuracy: 0.7365
# Epoch 19/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7369
# Epoch 20/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7371
# Epoch 21/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7379
# Epoch 22/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7376
# Epoch 23/30
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5414 - accuracy: 0.7382
# Epoch 24/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7381
# Epoch 25/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7387
# Epoch 26/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7386
# Epoch 27/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7383
# Epoch 28/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.7388
# Epoch 29/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7385
# Epoch 30/30
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5396 - accuracy: 0.7392

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5517 - accuracy: 0.7262 - 989ms/epoch - 4ms/step
# Loss: 0.5517457723617554, Accuracy: 0.7261807322502136

# %% [markdown]
# Automated Neural Network Optimization

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value= 90,
        step=5), activation=activation, input_dim=input_features))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 5)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=30,
            step=5),
            activation=activation))

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

    return nn_model

# %%
# !pip install keras_tuner
# Out:
# Collecting keras_tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (2.14.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (2.31.0)
# Collecting kt-legacy (from keras_tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2023.7.22)
# Installing collected packages: kt-legacy, keras_tuner
# Successfully installed keras_tuner-1.4.6 kt-legacy-1.0.5

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=50,
    hyperband_iterations=2)

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=50,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 87 Complete [00h 02m 14s]
# val_accuracy: 0.5331778526306152
#
# Best val_accuracy So Far: 0.7297959327697754
# Total elapsed time: 00h 42m 47s
#
# Search: Running Trial #88
#
# Value             |Best Value So Far |Hyperparameter
# tanh              |relu              |activation
# 61                |71                |first_units
# 2                 |5                 |num_layers
# 26                |21                |units_0
# 26                |16                |units_1
# 26                |6                 |units_2
# 6                 |6                 |units_3
# 21                |21                |units_4
# 50                |6                 |tuner/epochs
# 0                 |2                 |tuner/initial_epoch
# 0                 |3                 |tuner/bracket
# 0                 |1                 |tuner/round
#
# Epoch 1/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5691 - accuracy: 0.7214 - val_loss: 0.5598 - val_accuracy: 0.7245
# Epoch 2/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5566 - accuracy: 0.7307 - val_loss: 0.5561 - val_accuracy: 0.7265
# Epoch 3/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5529 - accuracy: 0.7317 - val_loss: 0.5562 - val_accuracy: 0.7250
# Epoch 4/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5516 - accuracy: 0.7322 - val_loss: 0.5558 - val_accuracy: 0.7271
# Epoch 5/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5506 - accuracy: 0.7325 - val_loss: 0.5559 - val_accuracy: 0.7278
# Epoch 6/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5490 - accuracy: 0.7341 - val_loss: 0.5537 - val_accuracy: 0.7272
# Epoch 7/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5475 - accuracy: 0.7324 - val_loss: 0.5530 - val_accuracy: 0.7257
# Epoch 8/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5468 - accuracy: 0.7345 - val_loss: 0.5547 - val_accuracy: 0.7252
# Epoch 9/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5468 - accuracy: 0.7339 - val_loss: 0.5526 - val_accuracy: 0.7249
# Epoch 10/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5453 - accuracy: 0.7357 - val_loss: 0.5532 - val_accuracy: 0.7266
# Epoch 11/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7361 - val_loss: 0.5532 - val_accuracy: 0.7266
# Epoch 12/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7363 - val_loss: 0.5521 - val_accuracy: 0.7268
# Epoch 13/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5442 - accuracy: 0.7353 - val_loss: 0.5525 - val_accuracy: 0.7276
# Epoch 14/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5436 - accuracy: 0.7358 - val_loss: 0.5510 - val_accuracy: 0.7277
# Epoch 15/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5433 - accuracy: 0.7372 - val_loss: 0.5524 - val_accuracy: 0.7271
# Epoch 16/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5425 - accuracy: 0.7368 - val_loss: 0.5520 - val_accuracy: 0.7272
# Epoch 17/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5424 - accuracy: 0.7376 - val_loss: 0.5518 - val_accuracy: 0.7275
# Epoch 18/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5413 - accuracy: 0.7371 - val_loss: 0.5506 - val_accuracy: 0.7290
# Epoch 19/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5414 - accuracy: 0.7383 - val_loss: 0.5528 - val_accuracy: 0.7251
# Epoch 20/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5409 - accuracy: 0.7373 - val_loss: 0.5537 - val_accuracy: 0.7258
# Epoch 21/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5410 - accuracy: 0.7381 - val_loss: 0.5515 - val_accuracy: 0.7259
# Epoch 22/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5406 - accuracy: 0.7372 - val_loss: 0.5521 - val_accuracy: 0.7272
# Epoch 23/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5400 - accuracy: 0.7387 - val_loss: 0.5506 - val_accuracy: 0.7265
# Epoch 24/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5398 - accuracy: 0.7384 - val_loss: 0.5507 - val_accuracy: 0.7275
# Epoch 25/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7385 - val_loss: 0.5517 - val_accuracy: 0.7252
# Epoch 26/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5395 - accuracy: 0.7386 - val_loss: 0.5518 - val_accuracy: 0.7270
# Epoch 27/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5394 - accuracy: 0.7390 - val_loss: 0.5509 - val_accuracy: 0.7266
# Epoch 28/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5389 - accuracy: 0.7395 - val_loss: 0.5514 - val_accuracy: 0.7231
# Epoch 29/50
# 221/804 [=======>......................] - ETA: 2s - loss: 0.5421 - accuracy: 0.7373
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-aa828f0678bd> in <cell line: 2>()
#       1 # Run the kerastuner search for best hyperparameters
# ----> 2 tuner.search(X_train_scaled,y_train,epochs=50,validation_data=(X_test_scaled,y_test))
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     231
#     232             self.on_trial_begin(trial)
# --> 233             self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     234             self.on_trial_end(trial)
#     235         self.on_search_end()
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py in _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     271     def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     272         try:
# --> 273             self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     274             trial.status = trial_module.TrialStatus.COMPLETED
#     275             return
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py in _run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     236
#     237     def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 238         results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     239         if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     240             self.oracle.objective.name
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/tuners/hyperband.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     425             fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426             fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427         return super().run_trial(trial, *fit_args, **fit_kwargs)
#     428
#     429     def _build_hypermodel(self, hp):
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     312             callbacks.append(model_checkpoint)
#     313             copied_kwargs["callbacks"] = callbacks
# --> 314             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     315
#     316             histories.append(obj_value)
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     231         hp = trial.hyperparameters
#     232         model = self._try_build(hp)
# --> 233         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     234
#     235         # Save the build config for model loading later.
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     147             If return a float, it should be the `objective` value.
#     148         """
# --> 149         return model.fit(*args, **kwargs)
#     150
#     151
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1772                 callbacks.on_epoch_begin(epoch)
#    1773                 with data_handler.catch_stop_iteration():
# -> 1774                     for step in data_handler.steps():
#    1775                         with tf.profiler.experimental.Trace(
#    1776                             "train",
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in steps(self)
#    1409             if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1410                 break
# -> 1411             original_spe = self._steps_per_execution.numpy().item()
#    1412             can_run_full_execution = (
#    1413                 original_spe == 1
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in numpy(self)
#     685   def numpy(self):
#     686     if context.executing_eagerly():
# --> 687       return self.read_value().numpy()
#     688     raise NotImplementedError(
#     689         "numpy() is only available when eager execution is enabled.")
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in read_value(self)
#     815     # Return an identity so it can get placed on whatever device the context
#     816     # specifies instead of the device where the variable is.
# --> 817     return array_ops.identity(value)
#     818
#     819   def read_value_no_copy(self):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1252         if iterable_params is not None:
#    1253           args, kwargs = replace_iterable_params(args, kwargs, iterable_params)
# -> 1254         result = api_dispatcher.Dispatch(args, kwargs)
#    1255         if result is not NotImplemented:
#    1256           return result
#
# KeyboardInterrupt:

# %%
# Get best model hyperparameters
best_hyper = tuner.get_best_hyperparameters()[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 71,
#  'num_layers': 5,
#  'units_0': 21,
#  'units_1': 16,
#  'units_2': 6,
#  'units_3': 6,
#  'units_4': 21,
#  'tuner/epochs': 6,
#  'tuner/initial_epoch': 2,
#  'tuner/bracket': 3,
#  'tuner/round': 1,
#  'tuner/trial_id': '0008'}

# %%
# Evaluate best model against full test data
best_model = tuner.get_best_models()[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5527 - accuracy: 0.7298 - 1s/epoch - 4ms/step
# Loss: 0.5527409315109253, Accuracy: 0.7297959327697754
